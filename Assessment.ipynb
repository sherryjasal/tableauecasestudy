# %%
import pandas as pd

# %%
df1 = pd.read_csv('Recruitment_Assessment/dim_order_details.csv')
df2 = pd.read_csv('Recruitment_Assessment/fct_orders.csv')

# %%
output1 = pd.merge(df1, df2, on='orderid', how='inner')

# %%
print(output1)
# Out:
#         orderid                  order_date  is_voucher  is_discount  \
# 0         61411  2020-01-01 01:05:24.000000       False        False
# 1         65675  2020-01-02 17:18:30.000000       False        False
# 2         52408  2020-01-04 17:59:42.000000       False        False
# 3         98735  2020-01-06 09:52:24.000000       False        False
# 4         52313  2020-01-07 19:49:35.000000       False        False
# 5        111115  2020-01-09 17:15:16.000000       False        False
# 6         48054  2020-01-11 15:11:08.000000       False        False
# 7         48060  2020-01-12 22:13:50.000000       False         True
# 8         98764  2020-01-14 19:46:49.000000       False        False
# 9         56717  2020-01-16 17:40:36.000000       False        False
# 10        65777  2020-01-18 14:35:51.000000       False        False
# 11        52507  2020-01-20 14:25:12.000000       False        False
# 12        36249  2020-01-22 14:49:56.000000       False        False
# ...

# %%
output1.duplicated(subset=['customerid'])
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
# 5         False
# 6         False
# 7          True
# 8         False
# 9         False
# 10        False
# 11        False
# 12        False
# 13        False
# 14         True
# 15        False
# 16        False
# 17        False
# 18        False
# 19        False
# 20        False
# 21        False
# 22        False
# 23        False
# 24        False
# 25        False
# 26        False
# 27         True
# 28        False
# 29        False
#           ...
# 127049    False
# 127050    False
# 127051    False
# 127052     True
# 127053    False
# 127054    False
# 127055    False
# 127056     True
# 127057    False
# 127058    False
# 127059    False
# 127060    False
# 127061    False
# 127062    False
# 127063    False
# 127064    False
# 127065    False
# 127066    False
# 127067     True
# 127068    False
# 127069    False
# 127070    False
# 127071    False
# 127072    False
# ...
